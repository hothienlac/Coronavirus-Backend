# %%
import bs4
import pandas as pd
import requests

# %%
url = 'https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Vietnam'
def get_page_contents(url):
    page = requests.get(url, headers={"Accept-Language": "en-US"})
    return bs4.BeautifulSoup(page.text, "html.parser")

ct = get_page_contents(url)

# %%
ct2 = ct.findAll( class_="wikitable")

ct3=ct2[2].findAll("td")

ct4=[content.text for content in ct3]

ct4= [element.rstrip("\n")for element in ct4]
main_data=[]
def chunker(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))
for group in chunker(ct4, 4):
    main_data.append(group)

# %%
df = pd.DataFrame(main_data, columns =['City / Province', 'Number of cases','Recovered','Deaths']) 
df.head()
# Out:
#     City / Province Number of cases Recovered Deaths
# 0             Hanoi             112        75      0
# 1  Ho Chi Minh City              55        53      0
# 2         Vinh Phuc              19        14      0
# 3         Ninh Binh              13        11      0
# 4        Binh Thuan               9         9      0

# %%
df = pd.read_html(ct3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-608accc257b0> in <module>
# ----> 1 df = pd.read_html(ct3)
#
# c:\program files\python37\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# c:\program files\python37\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# ...

# %%
ct2[1]
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Case
# </th>
# <th>Date
# </th>
# <th>Age
# </th>
# <th>Gender
# </th>
# <th>Nationality
# </th>
# <th>Place of detection
# </th>
# <th>Place of treatment
# </th>
# <th>Been to <a class="mw-redirect" href="/wiki/Wuhan,_Hubei" title="Wuhan, Hubei">Wuhan, Hubei</a>
# </th>
# <th>Been to <a class="mw-redirect" href="/wiki/2019-20_coronavirus_outbreak_by_country_and_territory" title="2019-20 coronavirus outbreak by country and territory">Covid-19 countries</a> (excluding <a href="/wiki/China" title="China">China</a>)
# </th>
# <th>Status
# </th>
# <th>Note
# </th>
# <th>Source
# </th></tr>
# <tr>
# <td>1
# </td>
# <td rowspan="2">23 January 2020
# </td>
# <td>66
# </td>
# <td rowspan="2">Male
# </td>
# ...

# %%
import pandas as pd


# Extract all tables from the wikipage
dfs = pd.read_html("https://en.wikipedia.org/wiki/2020_coronavirus_pandemic_in_Vietnam")
# The table referenced above is the 7th on the wikipage
df = dfs[2]
# The last row is just the date of the last update

# %%
df = dfs[5]
header = df.iloc[1].rename(None)
df = df[2:].reset_index(drop=True)
df.columns = header
df
# Out:
#             City / Province Number of cases Discharged Deaths
# 0                     Hanoi             112         75      0
# 1          Ho Chi Minh City              55         53      0
# 2                 Vinh Phuc              19         14      0
# 3                 Ninh Binh              13         11      0
# 4                Binh Thuan               9          9      0
# 5                Quang Ninh               7          7      0
# 6                   Da Nang               6          6      0
# 7                   Ha Tinh               4          3      0
# 8                    Ha Nam               4          4      0
# 9                 Bac Giang               4          4      0
# 10                Dong Thap               4          4      0
# 11                Thanh Hoa               3          2      0
# 12                 Tay Ninh               3          2      0
# 13                 Bac Lieu               3          3      0
# ...

# %%
df = dfs[4]

# %%
df.tail(20)
# Out:
#         Case          Date    Age            Gender    Nationality  \
# 199      228  3 April 2020     29              Male        Vietnam
# 200      229  3 April 2020     30            Female        Vietnam
# 201      230  3 April 2020     28            Female        Vietnam
# 202      231  3 April 2020     57            Female        Vietnam
# 203  232-233  3 April 2020  24-67  1 male, 1 female        Vietnam
# 204      234  3 April 2020     69            Female        Vietnam
# 205  235-236  3 April 2020  25-26  1 male, 1 female  Great Britain
# 206      237  3 April 2020     64              Male         Sweden
# 207      238  4 April 2020     17            Female        Vietnam
# 208      239  4 April 2020     71              Male        Vietnam
# 209      240  4 April 2020     29            Female        Vietnam
# 210      241  5 April 2020     20              Male        Vietnam
# 211      242  6 April 2020     34            Female        Vietnam
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 13 columns):
# Case                                            219 non-null object
# Date                                            219 non-null object
# Age                                             219 non-null object
# Gender                                          219 non-null object
# Nationality                                     219 non-null object
# Place of detection                              219 non-null object
# Place of treatment                              219 non-null object
# Been to Wuhan, Hubei                            219 non-null object
# Been to Covid-19 countries (excluding China)    219 non-null object
# Status                                          219 non-null object
# Note                                            117 non-null object
# Source                                          195 non-null object
# ...
